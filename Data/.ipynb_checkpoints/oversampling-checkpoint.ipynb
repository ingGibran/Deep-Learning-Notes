# %% [markdown]
# ## Libraries

# %%
import os

os.environ["HSA_OVERRIDE_GFX_VERSION"] = "10.3.0"

# %%
import numpy as np 

import torch 
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, Subset
from torchvision import datasets, transforms

import matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset

# %%
# Transform to turn into tensor and normalize
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307),(0.3081,)) # mean y std
])

# Load the dataset and normalize it
full_train_dataset = datasets.MNIST(
    root='./data',
    train=True,
    download=False,
    transform=transform
)

# Load the test dataset
full_test_dataset = datasets.MNIST(
    root='./data',
    train=False,
    download=False,
    transform=transform
)

# %% [markdown]
# ## Subsets

# %%
train_indices = torch.randperm(len(full_train_dataset))[:6000]
test_indices = torch.randperm(len(full_test_dataset))[:1000]

train_subset = Subset(full_train_dataset, train_indices)
test_subset = Subset(full_test_dataset, test_indices)

# %%
# DataLoaders
train_loader = DataLoader(
    dataset=train_subset,
    batch_size=64,
    num_workers=4,
    shuffle=True,
    drop_last=True
)

test_loader = DataLoader(
    dataset=test_subset,
    batch_size=64,
    num_workers=4,
    shuffle=True,
    drop_last=False
)

# %% [markdown]
# ## Train

# %%
def createTheMNISTNet():

    class mnistNet(nn.Module):
        def __init__(self):
            super().__init__()

            self.input = nn.Linear(784,64)

            self.fc1 = nn.Linear(64,32)
            self.fc2 = nn.Linear(32,32)

            self.output = nn.Linear(32,10)

        def forward(self,x):
            x = x.view(x.shape[0], -1)
            x = F.relu( self.input(x) )
            x = F.relu( self.fc1(x) )
            x = F.relu( self.fc2(x) )
            return self.output(x)

    net = mnistNet()

    lossfun = nn.CrossEntropyLoss()

    optimizer = torch.optim.SGD(net.parameters(), lr=.01)

    return net, lossfun, optimizer

# %%
def function2trainTheModel():

    numepochs = 50

    net, lossfun, optimizer = createTheMNISTNet()

    losses = torch.zeros(numepochs)
    trainAcc = []
    testAcc = []

    for epochi in range(numepochs):

        batchAcc = []
        batchLoss = []
        for X, y in train_loader:

            yHat = net(X)
            loss = lossfun(yHat,y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batchLoss.append(loss.item())

            matches = torch.argmax(yHat, axis=1) == y
            matchesNumeric = matches.float()
            accuracyPct = 100*torch.mean(matchesNumeric)
            batchAcc.append( accuracyPct )

        trainAcc.append( np.mean(batchAcc) )

        losses[epochi] = np.mean(batchLoss)

        X,y = next(iter(test_loader))
        with torch.no_grad():
            yHat = net(X)

        testAcc.append( 100*torch.mean((torch.argmax(yHat, axis=1)==y).float()) )

        print(f'Epoch: {epochi} \f trainAcc: {trainAcc[epochi]} \f testAcc: {testAcc[epochi]}')

    return trainAcc, testAcc, losses, net

# %%
trainAcc, testAcc, losses, net = function2trainTheModel()

fig, ax = plt.subplots(1,2, figsize=(16,5))

ax[0].plot(losses)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_ylim([0,3])
ax[0].set_title('Model loss')

ax[1].plot(trainAcc, label='Train')
ax[1].plot(testAcc, label='Test')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Accuracy (%)')
ax[1].set_ylim([10,100])
ax[1].set_title(f'Final model test accuracy: {testAcc[-1]:.2f}%')
ax[1].legend()

plt.show()
# Out:
# Epoch: 0  trainAcc: 13.978494644165039  testAcc: 17.1875
# Epoch: 1  trainAcc: 27.68817138671875  testAcc: 50.0
# Epoch: 2  trainAcc: 45.967742919921875  testAcc: 50.0
# Epoch: 3  trainAcc: 51.461692810058594  testAcc: 48.4375
# Epoch: 4  trainAcc: 59.61021423339844  testAcc: 73.4375
# Epoch: 5  trainAcc: 73.60551452636719  testAcc: 78.125
# Epoch: 6  trainAcc: 79.30107879638672  testAcc: 87.5
# Epoch: 7  trainAcc: 82.51007843017578  testAcc: 71.875
# Epoch: 8  trainAcc: 84.87903594970703  testAcc: 89.0625
# Epoch: 9  trainAcc: 86.7271499633789  testAcc: 89.0625
# Epoch: 10  trainAcc: 87.43279266357422  testAcc: 92.1875
# Epoch: 11  trainAcc: 88.42405700683594  testAcc: 85.9375
# Epoch: 12  trainAcc: 89.29771423339844  testAcc: 85.9375
# Epoch: 13  trainAcc: 89.56653594970703  testAcc: 90.625
# Epoch: 14  trainAcc: 90.0369644165039  testAcc: 90.625
# Epoch: 15  trainAcc: 90.57460021972656  testAcc: 93.75
# Epoch: 16  trainAcc: 90.82661437988281  testAcc: 90.625
# Epoch: 17  trainAcc: 90.86021423339844  testAcc: 93.75
# Epoch: 18  trainAcc: 91.24664306640625  testAcc: 90.625
# Epoch: 19  trainAcc: 91.51545715332031  testAcc: 92.1875
# Epoch: 20  trainAcc: 91.88507843017578  testAcc: 85.9375
# Epoch: 21  trainAcc: 92.1875  testAcc: 89.0625
# Epoch: 22  trainAcc: 92.23789978027344  testAcc: 87.5
# Epoch: 23  trainAcc: 92.55712127685547  testAcc: 89.0625
# Epoch: 24  trainAcc: 92.94355010986328  testAcc: 95.3125
# Epoch: 25  trainAcc: 92.90994262695312  testAcc: 90.625
# Epoch: 26  trainAcc: 93.24596405029297  testAcc: 93.75
# Epoch: 27  trainAcc: 93.31317138671875  testAcc: 90.625
# Epoch: 28  trainAcc: 93.54838562011719  testAcc: 90.625
# Epoch: 29  trainAcc: 93.75  testAcc: 89.0625
# Epoch: 30  trainAcc: 94.01881408691406  testAcc: 90.625
# Epoch: 31  trainAcc: 94.15322875976562  testAcc: 92.1875
# Epoch: 32  trainAcc: 94.38844299316406  testAcc: 87.5
# Epoch: 33  trainAcc: 94.57324981689453  testAcc: 92.1875
# Epoch: 34  trainAcc: 94.65725708007812  testAcc: 87.5
# Epoch: 35  trainAcc: 94.94287872314453  testAcc: 93.75
# Epoch: 36  trainAcc: 94.99327850341797  testAcc: 93.75
# Epoch: 37  trainAcc: 95.01007843017578  testAcc: 95.3125
# Epoch: 38  trainAcc: 95.36289978027344  testAcc: 85.9375
# Epoch: 39  trainAcc: 95.56451416015625  testAcc: 85.9375
# Epoch: 40  trainAcc: 95.3965072631836  testAcc: 89.0625
# Epoch: 41  trainAcc: 95.83333587646484  testAcc: 95.3125
# Epoch: 42  trainAcc: 95.96774291992188  testAcc: 85.9375
# Epoch: 43  trainAcc: 95.98454284667969  testAcc: 100.0
# Epoch: 44  trainAcc: 96.15255737304688  testAcc: 93.75
# Epoch: 45  trainAcc: 96.21975708007812  testAcc: 90.625
# Epoch: 46  trainAcc: 96.47177124023438  testAcc: 92.1875
# Epoch: 47  trainAcc: 96.50537872314453  testAcc: 93.75
# Epoch: 48  trainAcc: 96.5893783569336  testAcc: 95.3125
# Epoch: 49  trainAcc: 96.7909927368164  testAcc: 90.625
