# %% [markdown]
# # Linear Layer

# %%
import torch

# %%
x = torch.rand(3, 4)
print(x)
# Out:
# tensor([[0.4835, 0.0804, 0.1393, 0.2284],
#         [0.7693, 0.3666, 0.3419, 0.0840],
#         [0.7738, 0.0309, 0.5559, 0.8159]])

# %%
w = torch.rand(5, 4)
print(w)
# Out:
# tensor([[0.8885, 0.4532, 0.7116, 0.3728],
#         [0.2423, 0.7492, 0.4631, 0.0544],
#         [0.1731, 0.3037, 0.9086, 0.4073],
#         [0.4630, 0.3525, 0.6588, 0.1066],
#         [0.7298, 0.1742, 0.8056, 0.7668]])

# %%
# matrix multiplication
'''
mult = x @ w
'''
mult = x @ w.T
print(mult.shape)
print(mult)
# Out:
# torch.Size([3, 5])
# tensor([[0.6503, 0.2543, 0.3277, 0.3683, 0.6542],
#         [1.1243, 0.6240, 0.5894, 0.7196, 0.9652],
#         [1.4012, 0.5125, 0.9807, 0.8223, 1.6435]])
