# %% [markdown]
# # Tensor Operations

# %%
import torch 

A = torch.tensor([
    [1, 2],
    [3, 4]
])

B = torch.tensor([
    [5, 6],
    [7, 8]
])

print(f"Element-Wise: {A * B}")
print(f"Matmul: {A @ B}")
# Out:
# Element-Wise: tensor([[ 5, 12],
#         [21, 32]])
# Matmul: tensor([[19, 22],
#         [43, 50]])
