# %% [markdown]
# ## Import Libraries

# %%
import numpy as np

import torch 
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import matplotlib.pyplot as plt

# %% [markdown]
# ## Prepare train dataset

# %%
# Transform to turn into tensor and normalize
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307),(0.3081,)) # mean y std
])

# %%
# Load the dataset and normalize it
train_dataset = datasets.MNIST(
    root='./data',
    train=True,
    download=False,
    transform=transform
)

# %% [markdown]
# ## Prepare test dataset

# %%
transform_test = transforms.ToTensor()

# %%
# Load the test dataset
test_dataset = datasets.MNIST(
    root='./data',
    train=False,
    download=False,
    transform=transform_test
)

# %% [markdown]
# ## Data Loaders

# %%
# DataLoaders
train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=32,
    shuffle=True,
    drop_last=True
)

test_loader = DataLoader(
    dataset=test_dataset,
    batch_size=len(test_dataset[0][0][0])
)

# %% [markdown]
# ## Feed Forward Network

# %%
# All variables
# %whos
# Out:
# Variable         Type          Data/Info
# ----------------------------------------
# DataLoader       type          <class 'torch.utils.data.dataloader.DataLoader'>
# F                module        <module 'torch.nn.functio<...>/torch/nn/functional.py'>
# datasets         module        <module 'torchvision.data<...>on/datasets/__init__.py'>
# nn               module        <module 'torch.nn' from '<...>es/torch/nn/__init__.py'>
# np               module        <module 'numpy' from '/ho<...>kages/numpy/__init__.py'>
# plt              module        <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# test_dataset     MNIST         Dataset MNIST\n    Number<...>rm\nTransform: ToTensor()
# test_loader      DataLoader    <torch.utils.data.dataloa<...>object at 0x7fca9d825cd0>
# torch            module        <module 'torch' from '/ho<...>kages/torch/__init__.py'>
# train_dataset    MNIST         Dataset MNIST\n    Number<...>=(0.3081,))\n           )
# train_loader     DataLoader    <torch.utils.data.dataloa<...>object at 0x7fca9c93c6b0>
# transform        Compose       Compose(\n    ToTensor()\<...>0.1307, std=(0.3081,))\n)
# transform_test   ToTensor      ToTensor()
# transforms       module        <module 'torchvision.tran<...>/transforms/__init__.py'>

# %%
def createTheMNISTNet():

    class mnistNet(nn.Module):
        def __init__(self):
            super().__init__()

            # input layer
            self.input = nn.Linear(784,64) # 784 pixels

            # hidden layer
            self.fc1 = nn.Linear(64,32)
            self.fc2 = nn.Linear(32,32)

            # output layer
            self.output = nn.Linear(32,10)

        def forward(self,x):
            x = x.view(x.shape[0], -1)
            
            x = F.relu( self.input(x) )
            x = F.relu( self.fc1(x) )
            x = F.relu( self.fc2(x) )
            return torch.log_softmax( self.output(x), dim=1 )

    net = mnistNet()

    lossfun = nn.NLLLoss()

    optimizer = torch.optim.SGD(net.parameters(), lr=0.1) # try with Adam later

    return net, lossfun, optimizer

# %%
net, lossfun, optimizer = createTheMNISTNet()

X,y = next(iter(train_loader))
yHat = net(X)

print(yHat)

loss = lossfun(yHat, y)
print(' ')
print('Loss:')
print(loss)
# Out:
# tensor([[-2.0910, -2.2694, -2.2693, -2.2525, -2.4570, -2.3983, -2.3711, -2.3114,
#          -2.2193, -2.4443],
#         [-2.0955, -2.2776, -2.2694, -2.2359, -2.4448, -2.3947, -2.3845, -2.3092,
#          -2.1991, -2.4784],
#         [-2.1053, -2.2259, -2.2994, -2.2504, -2.4934, -2.4239, -2.3558, -2.3010,
#          -2.1892, -2.4492],
#         [-2.1116, -2.2321, -2.3059, -2.2597, -2.4834, -2.4015, -2.3469, -2.2880,
#          -2.2217, -2.4302],
#         [-2.0897, -2.2548, -2.2619, -2.2607, -2.5303, -2.4219, -2.3638, -2.2805,
#          -2.1842, -2.4569],
#         [-2.0701, -2.2775, -2.2895, -2.2542, -2.4433, -2.4142, -2.3700, -2.3241,
#          -2.1960, -2.4524],
#         [-2.0754, -2.2890, -2.2629, -2.2410, -2.4251, -2.4039, -2.3929, -2.3049,
#          -2.2027, -2.4980],
#         [-2.1065, -2.2310, -2.2779, -2.2658, -2.4394, -2.3951, -2.3779, -2.2930,
#          -2.2238, -2.4723],
#         [-2.0433, -2.2860, -2.2987, -2.2291, -2.4066, -2.4409, -2.3732, -2.3436,
#          -2.2081, -2.4720],
#         [-2.0854, -2.3013, -2.2624, -2.2394, -2.4217, -2.3888, -2.3938, -2.2917,
#          -2.2069, -2.5003],
#         [-2.0811, -2.2722, -2.2853, -2.2782, -2.4493, -2.3976, -2.3808, -2.2933,
#          -2.1807, -2.4739],
#         [-2.0822, -2.2435, -2.2977, -2.2569, -2.4718, -2.4055, -2.3998, -2.3108,
#          -2.1493, -2.4894],
#         [-2.0581, -2.2969, -2.2685, -2.2166, -2.3995, -2.4187, -2.3911, -2.3007,
#          -2.2492, -2.4977],
#         [-2.0827, -2.2756, -2.2532, -2.2530, -2.4350, -2.3983, -2.3885, -2.2995,
#          -2.2153, -2.4906],
#         [-2.0765, -2.2865, -2.2731, -2.2625, -2.4375, -2.3846, -2.3844, -2.3166,
#          -2.2000, -2.4667],
#         [-2.0925, -2.2722, -2.2562, -2.2658, -2.4808, -2.4011, -2.3690, -2.2873,
#          -2.1975, -2.4704],
#         [-2.1021, -2.2620, -2.2712, -2.2589, -2.4748, -2.3933, -2.3824, -2.2842,
#          -2.1835, -2.4810],
#         [-2.0928, -2.2578, -2.2849, -2.2525, -2.4479, -2.3872, -2.3803, -2.3063,
#          -2.2277, -2.4433],
#         [-2.1058, -2.2744, -2.2872, -2.2202, -2.4455, -2.3908, -2.3722, -2.3112,
#          -2.2148, -2.4602],
#         [-2.1168, -2.2400, -2.2951, -2.2605, -2.4329, -2.3804, -2.3635, -2.3035,
#          -2.2337, -2.4459],
#         [-2.0581, -2.2569, -2.2983, -2.2507, -2.4317, -2.4393, -2.3586, -2.3175,
#          -2.2204, -2.4635],
#         [-2.0686, -2.2923, -2.2632, -2.2574, -2.4369, -2.4005, -2.3798, -2.3087,
#          -2.2062, -2.4795],
#         [-2.0581, -2.2768, -2.2760, -2.2797, -2.4545, -2.4159, -2.3764, -2.3095,
#          -2.1662, -2.4927],
#         [-2.0844, -2.2599, -2.2809, -2.2424, -2.4335, -2.4027, -2.3801, -2.3147,
#          -2.2187, -2.4700],
#         [-2.0587, -2.2981, -2.2401, -2.2630, -2.4603, -2.4345, -2.3695, -2.2978,
#          -2.1795, -2.5096],
#         [-2.0551, -2.3093, -2.2692, -2.2631, -2.4281, -2.4265, -2.3777, -2.3085,
#          -2.1615, -2.5100],
#         [-2.0846, -2.2864, -2.2857, -2.2409, -2.4350, -2.3930, -2.3786, -2.3159,
#          -2.1971, -2.4707],
#         [-2.0702, -2.2822, -2.2806, -2.2421, -2.4143, -2.4080, -2.3843, -2.3149,
#          -2.2080, -2.4881],
#         [-2.0792, -2.2750, -2.2682, -2.2618, -2.4526, -2.3959, -2.3939, -2.2903,
#          -2.1875, -2.4933],
#         [-2.0705, -2.2423, -2.3100, -2.2900, -2.4599, -2.3969, -2.3812, -2.3174,
#          -2.1809, -2.4444],
#         [-2.0816, -2.2608, -2.3006, -2.2315, -2.4249, -2.4172, -2.3637, -2.3428,
#          -2.2132, -2.4501],
#         [-2.1049, -2.2278, -2.3086, -2.2811, -2.4970, -2.3860, -2.3887, -2.2831,
#          -2.1877, -2.4239]], grad_fn=<LogSoftmaxBackward0>)
#
# Loss:
# tensor(2.3163, grad_fn=<NllLossBackward0>)

# %% [markdown]
# ## Training

# %%
def function2trainTheModel():

    numepochs = 60

    net, loss, optimizer = createTheMNISTNet()

    losses = torch.zeros(numepochs)
    trainAcc = []
    testAcc = []

    for epochi in range(numepochs):

        # ===== Train =====
        batchAcc = []
        batchLoss = []
        for X,y in train_loader:
            
            # forward
            yHat = net(X)
            loss = lossfun(yHat, y)

            # back
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # loss
            batchLoss.append( loss.item() )

            # accuracy
            matches = torch.argmax(yHat, axis=1) == y # predictions
            matchesNumeric = matches.float() # to numeric
            accuracyPct = 100*torch.mean(matchesNumeric) # pct of mean
            batchAcc.append( accuracyPct ) # add

        trainAcc.append( np.mean(batchAcc) )

        losses[epochi] = np.mean(batchLoss)

        # ===== Test =====
        X,y = next(iter(test_loader))
        yHat = net(X)

        testAcc.append( 100*torch.mean( (torch.argmax(yHat, axis=1)==y).float() ) )

        print(f'Epoch: {epochi} \f trainAcc: {trainAcc[epochi]} \f testAcc: {testAcc[epochi]}')

    return trainAcc, testAcc, losses, net

# %%
trainAcc, testAcc, losses, net = function2trainTheModel()
# Out:
# Epoch: 0  trainAcc: 89.68000030517578  testAcc: 89.28571319580078
# Epoch: 1  trainAcc: 96.1683349609375  testAcc: 89.28571319580078
# Epoch: 2  trainAcc: 97.15333557128906  testAcc: 96.42857360839844
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 trainAcc, testAcc, losses, net = function2trainTheModel()
#
# Cell In[12], line 16, in function2trainTheModel()
#      12
#      13         # ===== Train =====
#      14         batchAcc = []
#      15         batchLoss = []
# ---> 16         for X,y in train_loader:
#      17
#      18             # forward
#      19             yHat = net(X)
#
# File ~/Documents/DLNotes/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File ~/Documents/DLNotes/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:801, in _SingleProcessDataLoaderIter._next_data(self)
#     799 def _next_data(self):
#     800     index = self._next_index()  # may raise StopIteration
# --> 801     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802     if self._pin_memory:
#     803         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/Documents/DLNotes/.venv/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52         data = self.dataset.__getitems__(possibly_batched_index)
#      53     else:
# ---> 54         data = [self.dataset[idx] for idx in possibly_batched_index]
#      55 else:
#      56     data = self.dataset[possibly_batched_index]
#
# File ~/Documents/DLNotes/.venv/lib/python3.12/site-packages/torchvision/datasets/mnist.py:139, in MNIST.__getitem__(self, index)
#     131 def __getitem__(self, index: int) -> tuple[Any, Any]:
#     132     """
#     133     Args:
#     134         index (int): Index
#    (...)    137         tuple: (image, target) where target is index of the target class.
#     138     """
# --> 139     img, target = self.data[index], int(self.targets[index])
#     141     # doing this so that it is consistent with all other datasets
#     142     # to return a PIL Image
#     143     img = _Image_fromarray(img.numpy(), mode="L")
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(1, 2, figsize=(16,5))

ax[0].plot(losses)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_ylim([0,3])
ax[0].set_title('Model loss')

ax[1].plot(trainAcc, label='Train')
ax[1].plot(testAcc, label='Test')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Accuracy (%)')
ax[1].set_ylim([10,100])
ax[1].set_title(f'Final model test accuracy: {testAcc[-1]:.2f}%')
ax[1].legend()
