# %% [markdown]
# ## Import Libraries

# %%
import os

os.environ["HSA_OVERRIDE_GFX_VERSION"] = "10.3.0"

# %%
import numpy as np

import torch 
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import matplotlib.pyplot as plt

# %% [markdown]
# ## Prepare train dataset

# %%
# Transform to turn into tensor and normalize
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307),(0.3081,)) # mean y std
])

# %%
# Load the dataset and normalize it
train_dataset = datasets.MNIST(
    root='./data',
    train=True,
    download=False,
    transform=transform
)

# %% [markdown]
# ## Prepare test dataset

# %%
transform_test = transforms.ToTensor()

# %%
# Load the test dataset
test_dataset = datasets.MNIST(
    root='./data',
    train=False,
    download=False,
    transform=transform_test
)

# %% [markdown]
# ## Data Loaders

# %%
# DataLoaders
train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=128,
    num_workers=4,
    shuffle=True,
    drop_last=True
)

test_loader = DataLoader(
    dataset=test_dataset,
    batch_size=256,
    num_workers=4,
    shuffle=True,
    drop_last=False
)

# %% [markdown]
# ## Feed Forward Network

# %%
# All variables
# %whos
# Out:
# Variable         Type          Data/Info
# ----------------------------------------
# DataLoader       type          <class 'torch.utils.data.dataloader.DataLoader'>
# F                module        <module 'torch.nn.functio<...>/torch/nn/functional.py'>
# datasets         module        <module 'torchvision.data<...>on/datasets/__init__.py'>
# nn               module        <module 'torch.nn' from '<...>es/torch/nn/__init__.py'>
# np               module        <module 'numpy' from '/ho<...>kages/numpy/__init__.py'>
# os               module        <module 'os' (frozen)>
# plt              module        <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# test_dataset     MNIST         Dataset MNIST\n    Number<...>rm\nTransform: ToTensor()
# test_loader      DataLoader    <torch.utils.data.dataloa<...>object at 0x754be1bf2e70>
# torch            module        <module 'torch' from '/ho<...>kages/torch/__init__.py'>
# train_dataset    MNIST         Dataset MNIST\n    Number<...>=(0.3081,))\n           )
# train_loader     DataLoader    <torch.utils.data.dataloa<...>object at 0x754be1b3e570>
# transform        Compose       Compose(\n    ToTensor()\<...>0.1307, std=(0.3081,))\n)
# transform_test   ToTensor      ToTensor()
# transforms       module        <module 'torchvision.tran<...>/transforms/__init__.py'>

# %%
import torch

print(f"¿GPU disponible?: {torch.cuda.is_available()}")
print(f"Nombre de la GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'Ninguna'}")
# Out:
# ¿GPU disponible?: True
# Nombre de la GPU: AMD Radeon RX 6600

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Entrenando en: {device}")
# Out:
# Entrenando en: cuda

# %%
def createTheMNISTNet():

    class mnistNet(nn.Module):
        def __init__(self):
            super().__init__()

            # input layer
            self.input = nn.Linear(784,64) # 784 pixels

            # hidden layer
            self.fc1 = nn.Linear(64,32)
            self.fc2 = nn.Linear(32,32)

            # output layer
            self.output = nn.Linear(32,10)

        def forward(self,x):
            x = x.view(x.shape[0], -1)
            
            x = F.relu( self.input(x) )
            x = F.relu( self.fc1(x) )
            x = F.relu( self.fc2(x) )
            return torch.log_softmax( self.output(x), dim=1 )

    net = mnistNet()

    lossfun = nn.NLLLoss()

    optimizer = torch.optim.SGD(net.parameters(), lr=0.1) # try with Adam later

    return net, lossfun, optimizer

# %%
net, lossfun, optimizer = createTheMNISTNet()

X,y = next(iter(train_loader))
yHat = net(X)

print(yHat)

loss = lossfun(yHat, y)
print(' ')
print('Loss:')
print(loss)
# Out:
# tensor([[-2.4846, -2.2305, -2.3349,  ..., -2.2411, -2.2456, -2.3436],
#         [-2.4542, -2.2858, -2.3473,  ..., -2.2195, -2.2361, -2.3303],
#         [-2.4507, -2.2468, -2.3655,  ..., -2.2378, -2.2367, -2.3490],
#         ...,
#         [-2.4440, -2.2799, -2.3988,  ..., -2.2368, -2.2345, -2.3272],
#         [-2.4355, -2.2557, -2.4032,  ..., -2.2694, -2.2826, -2.3382],
#         [-2.4504, -2.3020, -2.4061,  ..., -2.1717, -2.2791, -2.2993]],
#        grad_fn=<LogSoftmaxBackward0>)
#
# Loss:
# tensor(2.3162, grad_fn=<NllLossBackward0>)

# %% [markdown]
# ## Training

# %%
def function2trainTheModel():

    numepochs = 60

    net, lossfun, optimizer = createTheMNISTNet()
    net.to(device)

    losses = torch.zeros(numepochs)
    trainAcc = []
    testAcc = []

    for epochi in range(numepochs):

        # ===== Train =====
        batchAcc = []
        batchLoss = []
        for X,y in train_loader:

            X, y = X.to(device), y.to(device)
            
            # forward
            yHat = net(X)
            loss = lossfun(yHat, y)

            # back
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # loss
            batchLoss.append( loss.item() )

            # accuracy
            matches = torch.argmax(yHat, axis=1) == y # predictions
            matchesNumeric = matches.float() # to numeric
            accuracyPct = 100*torch.mean(matchesNumeric) # pct of mean
            batchAcc.append( accuracyPct.item() ) # add

        trainAcc.append( np.mean(batchAcc) )

        losses[epochi] = np.mean(batchLoss)

# Epoch: 33  trainAcc: 99.99833066239316  testAcc: 94.53125
# Epoch: 34  trainAcc: 99.99833066239316  testAcc: 94.53125
# Epoch: 35  trainAcc: 99.99833066239316  testAcc: 94.921875
# Epoch: 36  trainAcc: 99.99833066239316  testAcc: 94.53125
# Epoch: 37  trainAcc: 100.0  testAcc: 92.96875
# Epoch: 38  trainAcc: 100.0  testAcc: 93.75
# Epoch: 39  trainAcc: 100.0  testAcc: 94.53125
# Epoch: 40  trainAcc: 100.0  testAcc: 93.359375
# Epoch: 41  trainAcc: 100.0  testAcc: 94.140625
# Epoch: 42  trainAcc: 100.0  testAcc: 94.140625
# Epoch: 43  trainAcc: 100.0  testAcc: 92.1875
# Epoch: 44  trainAcc: 100.0  testAcc: 93.359375
# Epoch: 45  trainAcc: 100.0  testAcc: 92.96875
# Epoch: 46  trainAcc: 100.0  testAcc: 94.921875
# Epoch: 47  trainAcc: 100.0  testAcc: 94.53125
# Epoch: 48  trainAcc: 100.0  testAcc: 93.359375
# Epoch: 49  trainAcc: 100.0  testAcc: 97.265625
# Epoch: 50  trainAcc: 100.0  testAcc: 92.578125
# Epoch: 51  trainAcc: 100.0  testAcc: 90.625
# Epoch: 52  trainAcc: 100.0  testAcc: 93.359375
# Epoch: 53  trainAcc: 100.0  testAcc: 94.140625
# Epoch: 54  trainAcc: 100.0  testAcc: 92.96875
# Epoch: 55  trainAcc: 100.0  testAcc: 91.40625
# Epoch: 56  trainAcc: 100.0  testAcc: 96.09375
# Epoch: 57  trainAcc: 100.0  testAcc: 94.53125
# Epoch: 58  trainAcc: 100.0  testAcc: 95.703125
# Epoch: 59  trainAcc: 100.0  testAcc: 95.3125

# %%
fig, ax = plt.subplots(1, 2, figsize=(16,5))

ax[0].plot(losses)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_ylim([0,3])
ax[0].set_title('Model loss')

ax[1].plot(trainAcc, label='Train')
ax[1].plot(testAcc, label='Test')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Accuracy (%)')
ax[1].set_ylim([10,100])
ax[1].set_title(f'Final model test accuracy: {testAcc[-1]:.2f}%')
ax[1].legend()

# %%
X,y = next(iter(test_loader))
predictions = net(X).detach()

predictions
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 2
#       1 X,y = next(iter(test_loader))
# ----> 2 predictions = net(X).detach()
#       3
#       4 predictions
#
# File ~/Documents/DLNotes/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/DLNotes/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[11], line 20, in createTheMNISTNet.<locals>.mnistNet.forward(self, x)
#      17         def forward(self,x):
#      18             x = x.view(x.shape[0], -1)
#      19
# ---> 20             x = F.relu( self.input(x) )
#      21             x = F.relu( self.fc1(x) )
#      22             x = F.relu( self.fc2(x) )
#      23             return torch.log_softmax( self.output(x), dim=1 )
#
# File ~/Documents/DLNotes/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/DLNotes/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/DLNotes/.venv/lib/python3.12/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument mat1 in method wrapper_CUDA_addmm)

# %%
errors = np.where( torch.max(predictions, dim=1)[1] != y) [0]
print(errors)

sample2show = 4

fig, ax = plt.subplots(1,2,figsize=(14,5))

ax[0].bar(range(10), np.exp(predictions[errors[sample2show]]))
ax[0].set_xticks(range(10))
ax[0].set_xlabel('Number')
ax[0].set_ylabel('Evidence for that number')
ax[0].set_title(f'True number: {y[errors[sample2show]].item()}, model guessed{torch.argmax(predictions[errors[sample2show]]).item()}')
