# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
data = pd.read_csv('winequality-white.csv', sep=';')
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %% [markdown]
# ## Prepare Data

# %%
data['boolQuality'] = 0

data.loc[data['quality'] > 5, 'boolQuality'] = 1

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  boolQuality
# 0         8.8        6            1
# 1         9.5        6            1
# 2        10.1        6            1
# 3         9.9        6            1
# 4         9.9        6            1
# ...       ...      ...          ...
# 4893     11.2        6            1
# 4894      9.6        5            0
# 4895      9.4        6            1
# 4896     12.8        7            1
# 4897     11.8        6            1
#
# [4898 rows x 13 columns]

# %%
# Divide features and labels
X = data.drop(['quality', 'boolQuality'], axis=1)
y = data['boolQuality']

# Normalize data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# Separate 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, train_size=0.8)

# %%
# Store data into DataLoaders
import torch
from torch.utils.data import TensorDataset, DataLoader

train_data = TensorDataset(
    torch.tensor(X_train, dtype=torch.float32), 
    torch.tensor(y_train.to_numpy(), dtype=torch.float32)
)
test_data = TensorDataset(
    torch.tensor(X_test, dtype=torch.float32), 
    torch.tensor(y_test.to_numpy(), dtype=torch.float32)
)

train_loader = DataLoader(train_data, batch_size=16, shuffle=True, drop_last=True)
test_loader = DataLoader(test_data, batch_size=test_data.tensors[0].shape[0], drop_last=True)

# %% [markdown]
# ## ANN

# %%
import torch.nn as nn
class ANNModel(nn.Module):

    def __init__(self):
        super().__init__()

        self.model = nn.Sequential(
            nn.Linear(11, 64),
            nn.ReLU(),
            
            nn.Linear(64,32),
            nn.ReLU(),
            nn.Dropout(p=.20),

            nn.Linear(32, 1)
        )

    def forward(self, X):
        return self.model(X)

# %% [markdown]
# ## Initialize metaparameters

# %%
# Model = ANNModel()
model = ANNModel()

# Optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, weight_decay=1e-4)

# Loss Function
lossfun = nn.BCEWithLogitsLoss()

# %% [markdown]
# ## Train Model

# %%
model = model.to('cuda')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 model = model.to('cuda')
#
# File ~/Documents/DL-Course/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1381, in Module.to(self, *args, **kwargs)
#    1378         else:
#    1379             raise
# -> 1381 return self._apply(convert)
#
# File ~/Documents/DL-Course/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:933, in Module._apply(self, fn, recurse)
#     931 if recurse:
#     932     for module in self.children():
# --> 933         module._apply(fn)
#     935 from torch._subclasses.fake_tensor import FakeTensor
#     937 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
# File ~/Documents/DL-Course/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:933, in Module._apply(self, fn, recurse)
#     931 if recurse:
#     932     for module in self.children():
# --> 933         module._apply(fn)
#     935 from torch._subclasses.fake_tensor import FakeTensor
#     937 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
# File ~/Documents/DL-Course/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:964, in Module._apply(self, fn, recurse)
#     960 # Tensors stored in modules are graph leaves, and we don't want to
#     961 # track autograd history of `param_applied`, so we have to use
#     962 # `with torch.no_grad():`
#     963 with torch.no_grad():
# --> 964     param_applied = fn(param)
#     965 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     967 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~/Documents/DL-Course/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1367, in Module.to.<locals>.convert(t)
#    1360     if convert_to_format is not None and t.dim() in (4, 5):
#    1361         return t.to(
#    1362             device,
#    1363             dtype if t.is_floating_point() or t.is_complex() else None,
#    1364             non_blocking,
#    1365             memory_format=convert_to_format,
#    1366         )
# -> 1367     return t.to(
#    1368         device,
#    1369         dtype if t.is_floating_point() or t.is_complex() else None,
#    1370         non_blocking,
#    1371     )
#    1372 except NotImplementedError as e:
#    1373     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# File ~/Documents/DL-Course/.venv/lib/python3.12/site-packages/torch/cuda/__init__.py:424, in _lazy_init()
#     419     raise AssertionError(
#     420         "libcudart functions unavailable. It looks like you have a broken build?"
#     421     )
#     422 # This function throws if there's a driver initialization error, no GPUs
#     423 # are found or any other error occurs
# --> 424 torch._C._cuda_init()
#     425 # Some of the queued calls may reentrantly call _lazy_init();
#     426 # we need to just return without initializing in that case.
#     427 # However, we must not let any *other* threads in!
#     428 _tls.is_initializing = True
#
# RuntimeError: No CUDA GPUs are available

# %%
import numpy as np

epochs = 1000

trainAcc = []
testAcc = []
losses = []

for epochi in range(epochs):

    # ===== Train ======
    model.train()
    epoch_loss = 0
    batchAcc = []
    
    for X, y in train_loader:
        X = X.to('cuda')
        y = y.to('cuda')
        
        # Reshape y to match yHat's shape! ([batch_size] -> [batch_size, 1])
        y = y.unsqueeze(1) 

        # Forward
        yHat = model(X)
        loss = lossfun(yHat, y.view(-1, 1))
        
        # Back
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
        
        # Accuracy
        probs = torch.sigmoid(yHat)
        preds = (probs > 0.5).float()

        acc = 100*torch.mean((preds==y).float()).item()
        batchAcc.append(acc)

    trainAcc.append(np.mean(batchAcc))
    losses.append(acc)
    
    # ===== Test =====
    model.eval()
    batchAcc = []

    with torch.no_grad():
        for X, y in test_loader:
            X = X.to('cuda')
            y = y.to('cuda')
            
            # Reshape y here as well
            y = y.unsqueeze(1)

            # FIX: Pass X into the model, not y!
            yHat = model(X)

            # Accuracy
            probs = torch.sigmoid(yHat)
            preds = (probs > 0.5).float()
    
            acc = 100*torch.mean((preds==y).float()).item()
            
            batchAcc.append(acc)
        
        testAcc.append(np.mean(batchAcc))

    # FIX: Use epochi instead of epoch
    print(f"{epochi} | Train: {trainAcc[-1]:.2f} | Test: {testAcc[-1]:.2f}")

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,2, figsize=(10,5))

ax[0].plot(trainAcc)

ax[1].plot(testAcc)
